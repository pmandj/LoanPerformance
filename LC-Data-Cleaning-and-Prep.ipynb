# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#load all quarters 
q1 = pd.read_csv('LoanStats_2017Q1.csv.zip', skiprows=1, compression='zip', low_memory=False)
q2 = pd.read_csv('LoanStats_2017Q2.csv.zip', skiprows=1, compression='zip', low_memory=False)
q3 = pd.read_csv('LoanStats_2017Q3.csv.zip', skiprows=1, compression='zip', low_memory=False)
q4 = pd.read_csv('LoanStats_2017Q4.csv.zip', skiprows=1, compression='zip', low_memory=False)
#combine the quarters into a single dataset
df = pd.concat([q1,q2,q3,q4])

# %%
df.head()
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN    14000.0      14000.0          14000.0   60 months
# 1  NaN        NaN    15400.0      15400.0          15400.0   60 months
# 2  NaN        NaN     4600.0       4600.0           4600.0   36 months
# 3  NaN        NaN    15000.0      15000.0          15000.0   36 months
# 4  NaN        NaN    14000.0      14000.0          14000.0   36 months
#
#   int_rate  installment grade sub_grade       ...         \
# 0   12.74%       316.69     C        C1       ...
# 1   11.39%       337.84     B        B3       ...
# 2   11.39%       151.45     B        B3       ...
# 3    5.32%       451.73     A        A1       ...
# 4   15.99%       492.13     C        C5       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# ...

# %%
#renaming columns
df.rename(columns={'installment':'monthly_pmt'}, inplace=True)
df.head()
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN    14000.0      14000.0          14000.0   60 months
# 1  NaN        NaN    15400.0      15400.0          15400.0   60 months
# 2  NaN        NaN     4600.0       4600.0           4600.0   36 months
# 3  NaN        NaN    15000.0      15000.0          15000.0   36 months
# 4  NaN        NaN    14000.0      14000.0          14000.0   36 months
#
#   int_rate  monthly_pmt grade sub_grade       ...         \
# 0   12.74%       316.69     C        C1       ...
# 1   11.39%       337.84     B        B3       ...
# 2   11.39%       151.45     B        B3       ...
# 3    5.32%       451.73     A        A1       ...
# 4   15.99%       492.13     C        C5       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# ...

# %%
list(df.columns)
# Out:
# ['id',
#  'member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'monthly_pmt',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code',
#  'application_type',
# ...

# %%
#select only the columns you need from the data set and drop null vals
new_df=df.loc[:,['loan_amnt','term','int_rate','monthly_pmt','grade','issue_d','purpose', 'loan_status','dti','recoveries',
                'chargeoff_within_12_mths','all_util','tax_liens','pub_rec_bankruptcies','addr_state','delinq_2yrs',
                'delinq_amnt','annual_inc','num_tl_90g_dpd_24m','num_tl_30dpd']].dropna()

new_df.head()
# Out:
#    loan_amnt        term int_rate  monthly_pmt grade   issue_d  \
# 0    14000.0   60 months   12.74%       316.69     C  Mar-2017
# 1    15400.0   60 months   11.39%       337.84     B  Mar-2017
# 2     4600.0   36 months   11.39%       151.45     B  Mar-2017
# 3    15000.0   36 months    5.32%       451.73     A  Mar-2017
# 4    14000.0   36 months   15.99%       492.13     C  Mar-2017
#
#               purpose loan_status    dti  recoveries  \
# 0         credit_card     Current  17.48         0.0
# 1  debt_consolidation     Current  11.52         0.0
# 2         credit_card     Current  13.43         0.0
# 3  debt_consolidation     Current   9.35         0.0
# 4         credit_card     Current  31.07         0.0
#
#    chargeoff_within_12_mths  all_util  tax_liens  pub_rec_bankruptcies  \
# 0                       0.0      46.0        0.0                   0.0
# 1                       0.0      88.0        0.0                   0.0
# ...

# %%
#remove the % sign and the term 'months' from int_rate and term columns
#change the data type for each of the columns
new_df['term'] = new_df.term.str.replace('months', '').astype(int)
new_df['int_rate'] = new_df.int_rate.str.replace('%','').astype(float)
new_df['issue_d'] = new_df.issue_d.str.replace('-2017','')

# %%
#create a field that dislays ROI
new_df['total_return'] = new_df['term']*new_df['monthly_pmt']
new_df['roi'] = (new_df['total_return']/new_df['loan_amnt'])*100
new_df.head()
# Out:
#    loan_amnt  term  int_rate  monthly_pmt grade issue_d             purpose  \
# 0    14000.0    60     12.74       316.69     C     Mar         credit_card
# 1    15400.0    60     11.39       337.84     B     Mar  debt_consolidation
# 2     4600.0    36     11.39       151.45     B     Mar         credit_card
# 3    15000.0    36      5.32       451.73     A     Mar  debt_consolidation
# 4    14000.0    36     15.99       492.13     C     Mar         credit_card
#
#   loan_status    dti  recoveries     ...      tax_liens  pub_rec_bankruptcies  \
# 0     Current  17.48         0.0     ...            0.0                   0.0
# 1     Current  11.52         0.0     ...            0.0                   0.0
# 2     Current  13.43         0.0     ...            0.0                   0.0
# 3     Current   9.35         0.0     ...            0.0                   0.0
# 4     Current  31.07         0.0     ...            0.0                   0.0
#
# ...

# %%
#new_df.to_csv('full2017.csv')
